# %%
import pandas
df = pandas.read_csv("clean_data.csv")
#df = df[df["Attrition"] == "Yes"]

# %%
#Attrition and Retention Count among Overtime Workers
df["OverTime"].value_counts(normalize = True).mul(100).round(2).astype(str) + '%'
# Out:
# OverTime
# No     71.7%
# Yes    28.3%
# Name: proportion, dtype: object

# %%
#Job Satisfacation Distribution
df["JobSatisfaction"].value_counts(normalize = True).mul(100).round(2).sort_index().astype(str) + '%'
# Out:
# JobSatisfaction
# 1    19.66%
# 2    19.05%
# 3    30.07%
# 4    31.22%
# Name: proportion, dtype: object

# %%
#Job Satisfacation Distribution
df["WorkLifeBalance"].value_counts(normalize = True).mul(100).round(2).sort_index().astype(str) + '%'
# Out:
# WorkLifeBalance
# 1     5.44%
# 2     23.4%
# 3    60.75%
# 4    10.41%
# Name: proportion, dtype: object
